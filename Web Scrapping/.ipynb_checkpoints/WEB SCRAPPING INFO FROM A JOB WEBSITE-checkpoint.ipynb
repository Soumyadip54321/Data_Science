# %% [markdown]
# ## WEB CRAWLING A JOB WEBSITE TO EXTRACT ALL JOB RELATED INFO
# This workbook demonstrates usage of web scrapping to gather all job related information from a website

# %%
import os
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# We consider a website **Timesjobs** that has all job related information to scrape.

# %%
url="https://www.timesjobs.com/candidate/job-search.html?searchType=Home_Search&from=submit&asKey=OFF&txtKeywords=&cboPresFuncArea=35&clusterName=CLUSTER_FA&hc=CLUSTER_FA"

# %%
result=requests.get(url)

# %% [markdown]
# Check whether we indeed get a response or not.

# %%
result.status_code
# Out:
# 200

# %% [markdown]
# Now we create a file that stores the frontend code which then we open and convert into a string that we read from.

# %%
with open('timesjobs.html','w') as f:
    f.write(result.text)

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  'timesjobs.html',
#  'response.html',
#  '.jovianrc',
#  'WEB SCRAPPING.ipynb',
#  '.ipynb_checkpoints',
#  'WEB SCRAPPING INFO FROM A JOB WEBSITE.ipynb']

# %%
timesjobs_html_text=""
with open('timesjobs.html','r') as f:
    timesjobs_html_text+=f.read()

# %%
import lxml

# %%
soup=BeautifulSoup(timesjobs_html_text,'lxml')

# %%
print(soup.prettify)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
res=soup.find_all('li',class_='job-bx')

# %%
res
# Out:
# [<li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container">
#  <i class="default-company-logo"></i>
#  </span>
#  <div>
#  <h2 class="heading-trun" title="Manual Test Engineer Required in Canada Under PNP program">
#  <a href="https://www.timesjobs.com/job-detail/manual-test-engineer-required-in-canada-under-pnp-program-world-overseas-immigration-consultancy-pvt-ltd-australia-canada-2-to-7-yrs-jobid-NMmhRdQ1bIBzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69387137','software , software engineer , software developer , programmer , web developer , Manual Testing , Automated Testing  Manual Testing , Automation Manual Testing','Australia,  Canada','2 - 7','IT Software : Software Products &amp; Services','1','' )" target="_blank">
#        Manual Test Engineer Required in Canada Under PNP program</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    World Overseas immigration Consultancy Pvt Ltd
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			Work with developers to design algorithms and flowcharts.Produce clean, efficient code based on specifications.Integrate software components and third...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					software
#     				</span>
#  <span>
#     					software engineer
#     				</span>
#  <span>
#     					software developer
#     				</span>
#  <span>
#     					programmer
#     				</span>
#  <span>
#     					web developer
#     				</span>
#  <span>
#     					Manual Testing
#     				</span>
#  <span>
#     					Automated Testing  Manual Testing
#     				</span>
#  <span>
#     					Automation Manual Testing
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Australia,  Canada">
#  <i class="srp-icons location"></i>
#
#                Australia,  Canada
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>2 - 7 Years</li>
#  <li><i class="srp-icons salary" data-highsalary="4420000" data-lowsalary="3915000"></i>
#            		39
#            		-
#            		44
#            		Lakhs</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_69387137">
#  <button class="apply-btn" id="apply_69387137" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_others');jobSRPApplyFuncInline('69387137','INT','TJPFSRP');logViewUSBT('apply','69387137','software , software engineer , software developer , programmer , web developer , Manual Testing , Automated Testing  Manual Testing , Automation Manual Testing','Australia,  Canada','2 - 7','IT Software : Software Products &amp; Services','1','')">View Details</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Australia,  Canada
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/manual-test-engineer-required-in-canada-under-pnp-program-world-overseas-immigration-consultancy-pvt-ltd-australia-canada-2-to-7-yrs-jobid-NMmhRdQ1bIBzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69387137','software , software engineer , software developer , programmer , web developer , Manual Testing , Automated Testing  Manual Testing , Automation Manual Testing','Australia,  Canada','2 - 7','IT Software : Software Products &amp; Services','1','' )" target="_blank"></a>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container">
#  <i class="default-company-logo"></i>
#  </span>
#  <div>
#  <h2 class="heading-trun" title="Power Platform Developer">
#  <a href="https://www.timesjobs.com/job-detail/power-platform-developer-d-b-consultancy-bengaluru-bangalore-pune-5-to-10-yrs-jobid-tlOApf1uXzlzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70781437','PowerApps , Power Automate , SQL , Power Platform Developer , Power Platform , designing , developing , stakeholders , prototyping , Power Apps canvas , Troubleshooting','Bengaluru / Bangalore,  Pune','5 - 10','IT Software : Software Products &amp; Services','2','' )" target="_blank">
#        Power Platform Developer</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    D B Consultancy
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			Urgent opening for Power Platform Developer-Pune/BangalorePosition:Power Platform DeveloperExperience:5+YearsBudget:10-12LPA(Slightly negotiable)Locat...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					PowerApps
#     				</span>
#  <span>
#     					Power Automate
#     				</span>
#  <span>
#     					SQL
#     				</span>
#  <span>
#     					Power Platform Developer
#     				</span>
#  <span>
#     					Power Platform
#     				</span>
#  <span>
#     					designing
#     				</span>
#  <span>
#     					developing
#     				</span>
#  <span>
#     					stakeholders
#     				</span>
#  <span>
#     					prototyping
#     				</span>
#  <span>
#     					Power Apps canvas
#     				</span>
#  <span>
#     					Troubleshooting
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Bengaluru / Bangalore,  Pune">
#  <i class="srp-icons location"></i>
#
#                Bengaluru / Bangalore,  Pune
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>5 - 10 Years</li>
#  <li><i class="srp-icons salary"></i>Not disclosed</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70781437">
#  <button class="apply-btn" id="apply_70781437" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_others');jobSRPApplyFuncInline('70781437','INT','TJPFSRP');logViewUSBT('apply','70781437','PowerApps , Power Automate , SQL , Power Platform Developer , Power Platform , designing , developing , stakeholders , prototyping , Power Apps canvas , Troubleshooting','Bengaluru / Bangalore,  Pune','5 - 10','IT Software : Software Products &amp; Services','2','')">View Details</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Bengaluru / Bangalore,  Pune
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/power-platform-developer-d-b-consultancy-bengaluru-bangalore-pune-5-to-10-yrs-jobid-tlOApf1uXzlzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70781437','PowerApps , Power Automate , SQL , Power Platform Developer , Power Platform , designing , developing , stakeholders , prototyping , Power Apps canvas , Troubleshooting','Bengaluru / Bangalore,  Pune','5 - 10','IT Software : Software Products &amp; Services','2','' )" target="_blank"></a>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container">
#  <i class="default-company-logo"></i>
#  </span>
#  <div>
#  <h2 class="heading-trun" title="Software Engineer\Sr. Software Engineer - J48459">
#  <a href="https://www.timesjobs.com/job-detail/software-engineer-sr-software-engineer-j48459-sampoorna-consultants-pvt-ltd-bengaluru-bangalore-4-to-7-yrs-jobid-__PLUS__Dz2P__SLASH__ZZsiZzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70781436','Data Engineer','Bengaluru / Bangalore','4 - 7','IT Software : Software Products &amp; Services','3','' )" target="_blank">
#        Software Engineer\Sr. Software Engineer - J48459</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    SAMPOORNA CONSULTANTS PVT LTD
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			Knowledge/Qualifications/ Technical Competencies Knowledge, Skills &amp; Abilities:  Develop and maintain automated test suites, using Python/Scala/C#...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					Data Engineer
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Bengaluru / Bangalore">
#  <i class="srp-icons location"></i>
#
#                Bengaluru / Bangalore
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>4 - 7 Years</li>
#  <li><i class="srp-icons salary" data-highsalary="2000000" data-lowsalary="700000"></i>
#            		7
#            		-
#            		20
#            		Lakhs</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70781436">
#  <button class="apply-btn" id="apply_70781436" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_others');jobSRPApplyFuncInline('70781436','INT','TJPFSRP');logViewUSBT('apply','70781436','Data Engineer','Bengaluru / Bangalore','4 - 7','IT Software : Software Products &amp; Services','3','')">View Details</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Bengaluru / Bangalore
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/software-engineer-sr-software-engineer-j48459-sampoorna-consultants-pvt-ltd-bengaluru-bangalore-4-to-7-yrs-jobid-__PLUS__Dz2P__SLASH__ZZsiZzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70781436','Data Engineer','Bengaluru / Bangalore','4 - 7','IT Software : Software Products &amp; Services','3','' )" target="_blank"></a>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container">
#  <i class="default-company-logo"></i>
#  </span>
#  <div>
#  <h2 class="heading-trun" title="Innovation Engineer - AI - J48457">
#  <a href="https://www.timesjobs.com/job-detail/innovation-engineer-ai-j48457-sampoorna-consultants-pvt-ltd-bengaluru-bangalore-chennai-3-to-5-yrs-jobid-D3OKrJqc3ZRzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70781435','Python , AI','Bengaluru / Bangalore,  Chennai','3 - 5','IT Software : Software Products &amp; Services','4','' )" target="_blank">
#        Innovation Engineer - AI - J48457</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    SAMPOORNA CONSULTANTS PVT LTD
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			As an Innovation Engineer at , you will collaborate with technical teams to identify andimplement opportunities to apply AI, machine learning, and adv...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					Python
#     				</span>
#  <span>
#     					AI
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Bengaluru / Bangalore,  Chennai">
#  <i class="srp-icons location"></i>
#
#                Bengaluru / Bangalore,  Chennai
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>3 - 5 Years</li>
#  <li><i class="srp-icons salary" data-highsalary="1300000" data-lowsalary="600000"></i>
#            		6
#            		-
#            		13
#            		Lakhs</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70781435">
#  <button class="apply-btn" id="apply_70781435" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_others');jobSRPApplyFuncInline('70781435','INT','TJPFSRP');logViewUSBT('apply','70781435','Python , AI','Bengaluru / Bangalore,  Chennai','3 - 5','IT Software : Software Products &amp; Services','4','')">View Details</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Bengaluru / Bangalore,  Chennai
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/innovation-engineer-ai-j48457-sampoorna-consultants-pvt-ltd-bengaluru-bangalore-chennai-3-to-5-yrs-jobid-D3OKrJqc3ZRzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70781435','Python , AI','Bengaluru / Bangalore,  Chennai','3 - 5','IT Software : Software Products &amp; Services','4','' )" target="_blank"></a>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container">
#  <i class="default-company-logo"></i>
#  </span>
#  <div>
#  <h2 class="heading-trun" title="Data Analyst - AI/ML - J48458">
#  <a href="https://www.timesjobs.com/job-detail/data-analyst-ai-ml-j48458-sampoorna-consultants-pvt-ltd-chennai-3-to-5-yrs-jobid-cysV91wpAnlzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70781434','AI / ML','Chennai','3 - 5','IT Software : Software Products &amp; Services','5','' )" target="_blank">
#        Data Analyst - AI/ML - J48458</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    SAMPOORNA CONSULTANTS PVT LTD
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			Data Analyst :At least 2 years of experience in data analysis, data engineering, or a similar role. Proficient in SQL and at least one programming lan...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					AI / ML
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Chennai">
#  <i class="srp-icons location"></i>
#
#                Chennai
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>3 - 5 Years</li>
#  <li><i class="srp-icons salary" data-highsalary="1300000" data-lowsalary="600000"></i>
#            		6
#            		-
#            		13
#            		Lakhs</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70781434">
#  <button class="apply-btn" id="apply_70781434" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_others');jobSRPApplyFuncInline('70781434','INT','TJPFSRP');logViewUSBT('apply','70781434','AI / ML','Chennai','3 - 5','IT Software : Software Products &amp; Services','5','')">View Details</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Chennai
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/data-analyst-ai-ml-j48458-sampoorna-consultants-pvt-ltd-chennai-3-to-5-yrs-jobid-cysV91wpAnlzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70781434','AI / ML','Chennai','3 - 5','IT Software : Software Products &amp; Services','5','' )" target="_blank"></a>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container">
#  <i class="default-company-logo"></i>
#  </span>
#  <div>
#  <h2 class="heading-trun" title=".NET  API + Azure-(UK) - Con- BLR - J48411">
#  <a href="https://www.timesjobs.com/job-detail/net-api-azure-uk-con-blr-j48411-sampoorna-consultants-pvt-ltd-bengaluru-bangalore-5-to-6-yrs-jobid-R7AnUOjPiGFzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70781433','.net','Bengaluru / Bangalore','5 - 6','IT Software : Software Products &amp; Services','6','' )" target="_blank">
#        .NET  API + Azure-(UK) - Con- BLR - J48411</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    SAMPOORNA CONSULTANTS PVT LTD
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			Key Responsibilities:Design, develop, and maintain software applications using C# and .NET.Collaborate with the team to build responsive front-end int...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					.net
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Bengaluru / Bangalore">
#  <i class="srp-icons location"></i>
#
#                Bengaluru / Bangalore
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>5 - 6 Years</li>
#  <li><i class="srp-icons salary" data-highsalary="2200000" data-lowsalary="1200000"></i>
#            		12
#            		-
#            		22
#            		Lakhs</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70781433">
#  <button class="apply-btn" id="apply_70781433" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_others');jobSRPApplyFuncInline('70781433','INT','TJPFSRP');logViewUSBT('apply','70781433','.net','Bengaluru / Bangalore','5 - 6','IT Software : Software Products &amp; Services','6','')">View Details</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Bengaluru / Bangalore
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/net-api-azure-uk-con-blr-j48411-sampoorna-consultants-pvt-ltd-bengaluru-bangalore-5-to-6-yrs-jobid-R7AnUOjPiGFzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70781433','.net','Bengaluru / Bangalore','5 - 6','IT Software : Software Products &amp; Services','6','' )" target="_blank"></a>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000291.png" alt="Capgemini India Pvt Ltd" title="Capgemini India Pvt Ltd"/> </span> -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container"><img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000291.png"/>
#  </span>
#  <div>
#  <h2 class="heading-trun" title="Systems Engineer - C">
#  <a href="https://www.timesjobs.com/job-detail/systems-engineer-c-capgemini-india-pvt-ltd-bengaluru-bangalore-3-to-5-yrs-jobid-1y9NDAfzeG5zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70699855','operating system installation  ,  system maintenance support  ,  incident troubleshooting  ,  security &amp; backup management  ,  emerging technologies development  , patching','Bengaluru / Bangalore','3 - 5','IT Software : Software Products &amp; Services','7','' )" target="_blank">
#        Systems Engineer - C</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    Capgemini India Pvt Ltd
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			Responsible for the operations and maintenance of On Premise or client dedicated computing platforms and servers. They install, maintain, patch, upgra...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					operating system installation
#     				</span>
#  <span>
#     					system maintenance support
#     				</span>
#  <span>
#     					incident troubleshooting
#     				</span>
#  <span>
#     					security &amp; backup management
#     				</span>
#  <span>
#     					emerging technologies development
#     				</span>
#  <span>
#     					patching
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Bengaluru / Bangalore">
#  <i class="srp-icons location"></i>
#
#                Bengaluru / Bangalore
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>3 - 5 Years</li>
#  <li><i class="srp-icons salary"></i>Not disclosed</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70699855">
#  <a class="apply-btn" href="javascript:callExtJobApply('70699855','adId=1y9NDAfzeG5zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70699855','operating system installation  ,  system maintenance support  ,  incident troubleshooting  ,  security &amp; backup management  ,  emerging technologies development  , patching','Bengaluru / Bangalore','3 - 5','IT Software : Software Products &amp; Services','7','')">View Details</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Bengaluru / Bangalore
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/systems-engineer-c-capgemini-india-pvt-ltd-bengaluru-bangalore-3-to-5-yrs-jobid-1y9NDAfzeG5zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70699855','operating system installation  ,  system maintenance support  ,  incident troubleshooting  ,  security &amp; backup management  ,  emerging technologies development  , patching','Bengaluru / Bangalore','3 - 5','IT Software : Software Products &amp; Services','7','' )" target="_blank"></a>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000291.png" alt="Capgemini India Pvt Ltd" title="Capgemini India Pvt Ltd"/> </span> -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container"><img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000291.png"/>
#  </span>
#  <div>
#  <h2 class="heading-trun" title="Senior Software Engineer - C">
#  <a href="https://www.timesjobs.com/job-detail/senior-software-engineer-c-capgemini-india-pvt-ltd-gurgaon-3-to-5-yrs-jobid-WcIsks16__PLUS__EdzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70699851','wireless technologies  ,  packet core integration  ,  network troubleshooting  ,  diagnostic procedures  ,  gpp specifications  , c   , html5 , rest api , advanced c , java , devops , xml , c# , github , software testing , javascript , messaging , nosql , groovy , struts , hybris , software design , jsp , ado.net , hibernate , spring mvc','Gurgaon','3 - 5','IT Software : Software Products &amp; Services','8','' )" target="_blank">
#        Senior Software Engineer - C</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    Capgemini India Pvt Ltd
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			Responsible for the Configuration, Testing, Troubleshooting, and Operations of Ericsson PaCo Nes(vSGSN-MME, vEPG, WMG).Must have a strong understandin...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					wireless technologies
#     				</span>
#  <span>
#     					packet core integration
#     				</span>
#  <span>
#     					network troubleshooting
#     				</span>
#  <span>
#     					diagnostic procedures
#     				</span>
#  <span>
#     					gpp specifications
#     				</span>
#  <span>
#     					c
#     				</span>
#  <span>
#     					html5
#     				</span>
#  <span>
#     					rest api
#     				</span>
#  <span>
#     					advanced c
#     				</span>
#  <span>
#     					java
#     				</span>
#  <span>
#     					devops
#     				</span>
#  <span>
#     					xml
#     				</span>
#  <span>
#     					c#
#     				</span>
#  <span>
#     					github
#     				</span>
#  <span>
#     					software testing
#     				</span>
#  <span>
#     					javascript
#     				</span>
#  <span>
#     					messaging
#     				</span>
#  <span>
#     					nosql
#     				</span>
#  <span>
#     					groovy
#     				</span>
#  <span>
#     					struts
#     				</span>
#  <span>
#     					hybris
#     				</span>
#  <span>
#     					software design
#     				</span>
#  <span>
#     					jsp
#     				</span>
#  <span>
#     					ado.net
#     				</span>
#  <span>
#     					hibernate
#     				</span>
#  <span>
#     					spring mvc
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Gurgaon">
#  <i class="srp-icons location"></i>
#
#                Gurgaon
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>3 - 5 Years</li>
#  <li><i class="srp-icons salary"></i>Not disclosed</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70699851">
#  <a class="apply-btn" href="javascript:callExtJobApply('70699851','adId=WcIsks16__PLUS__EdzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70699851','wireless technologies  ,  packet core integration  ,  network troubleshooting  ,  diagnostic procedures  ,  gpp specifications  , c   , html5 , rest api , advanced c , java , devops , xml , c# , github , software testing , javascript , messaging , nosql , groovy , struts , hybris , software design , jsp , ado.net , hibernate , spring mvc','Gurgaon','3 - 5','IT Software : Software Products &amp; Services','8','')">View Details</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Gurgaon
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/senior-software-engineer-c-capgemini-india-pvt-ltd-gurgaon-3-to-5-yrs-jobid-WcIsks16__PLUS__EdzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70699851','wireless technologies  ,  packet core integration  ,  network troubleshooting  ,  diagnostic procedures  ,  gpp specifications  , c   , html5 , rest api , advanced c , java , devops , xml , c# , github , software testing , javascript , messaging , nosql , groovy , struts , hybris , software design , jsp , ado.net , hibernate , spring mvc','Gurgaon','3 - 5','IT Software : Software Products &amp; Services','8','' )" target="_blank"></a>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000291.png" alt="Capgemini India Pvt Ltd" title="Capgemini India Pvt Ltd"/> </span> -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container"><img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000291.png"/>
#  </span>
#  <div>
#  <h2 class="heading-trun" title="Data Engineer - C">
#  <a href="https://www.timesjobs.com/job-detail/data-engineer-c-capgemini-india-pvt-ltd-pune-5-to-8-yrs-jobid-qm4d__PLUS__eVT3L1zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70699840','data engineering leadership  ,  data architecture patterns  ,  project management  ,  stakeholder management  ,  continuous integration and delivery  , hql , sun solaris , apache , devops , python , oracle , ubuntu , javascript , scala , storage , sql , database , git , linux , hadoop , perl , sas , ibm db2 , infrastructure','Pune','5 - 8','IT Software : Software Products &amp; Services','9','' )" target="_blank">
#        Data Engineer - C</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    Capgemini India Pvt Ltd
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			Data engineers are responsible for building reliable and scalable data infrastructure that enables organizations to derive meaningful insights, make d...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					data engineering leadership
#     				</span>
#  <span>
#     					data architecture patterns
#     				</span>
#  <span>
#     					project management
#     				</span>
#  <span>
#     					stakeholder management
#     				</span>
#  <span>
#     					continuous integration and delivery
#     				</span>
#  <span>
#     					hql
#     				</span>
#  <span>
#     					sun solaris
#     				</span>
#  <span>
#     					apache
#     				</span>
#  <span>
#     					devops
#     				</span>
#  <span>
#     					python
#     				</span>
#  <span>
#     					oracle
#     				</span>
#  <span>
#     					ubuntu
#     				</span>
#  <span>
#     					javascript
#     				</span>
#  <span>
#     					scala
#     				</span>
#  <span>
#     					storage
#     				</span>
#  <span>
#     					sql
#     				</span>
#  <span>
#     					database
#     				</span>
#  <span>
#     					git
#     				</span>
#  <span>
#     					linux
#     				</span>
#  <span>
#     					hadoop
#     				</span>
#  <span>
#     					perl
#     				</span>
#  <span>
#     					sas
#     				</span>
#  <span>
#     					ibm db2
#     				</span>
#  <span>
#     					infrastructure
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Pune">
#  <i class="srp-icons location"></i>
#
#                Pune
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>5 - 8 Years</li>
#  <li><i class="srp-icons salary"></i>Not disclosed</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70699840">
#  <a class="apply-btn" href="javascript:callExtJobApply('70699840','adId=qm4d__PLUS__eVT3L1zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70699840','data engineering leadership  ,  data architecture patterns  ,  project management  ,  stakeholder management  ,  continuous integration and delivery  , hql , sun solaris , apache , devops , python , oracle , ubuntu , javascript , scala , storage , sql , database , git , linux , hadoop , perl , sas , ibm db2 , infrastructure','Pune','5 - 8','IT Software : Software Products &amp; Services','9','')">View Details</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Pune
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/data-engineer-c-capgemini-india-pvt-ltd-pune-5-to-8-yrs-jobid-qm4d__PLUS__eVT3L1zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70699840','data engineering leadership  ,  data architecture patterns  ,  project management  ,  stakeholder management  ,  continuous integration and delivery  , hql , sun solaris , apache , devops , python , oracle , ubuntu , javascript , scala , storage , sql , database , git , linux , hadoop , perl , sas , ibm db2 , infrastructure','Pune','5 - 8','IT Software : Software Products &amp; Services','9','' )" target="_blank"></a>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000291.png" alt="Capgemini India Pvt Ltd" title="Capgemini India Pvt Ltd"/> </span> -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container"><img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000291.png"/>
#  </span>
#  <div>
#  <h2 class="heading-trun" title="Java Angular | 4 to 8 years | Pune &amp; Hyderabad">
#  <a href="https://www.timesjobs.com/job-detail/java-angular-4-to-8-years-pune-hyderabad-capgemini-india-pvt-ltd-pune-4-to-8-yrs-jobid-FlEnn8GTIRdzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70699838','fullstack development   ,  angular framework   ,  mongodb database   ,  java spring boot   ,  microservices architecture   , apache , git , docker','Pune','4 - 8','IT Software : Software Products &amp; Services','10','' )" target="_blank">
#        Java Angular | 4 to 8 years | Pune &amp; Hyderabad</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    Capgemini India Pvt Ltd
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			Experience: 4 to 8 years in FULLSTACK ANGULAR, MONGODB.Technical Skills: Hands-on experience in web services, microservices, Java 8 , Spring Boot.Good...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					fullstack development
#     				</span>
#  <span>
#     					angular framework
#     				</span>
#  <span>
#     					mongodb database
#     				</span>
#  <span>
#     					java spring boot
#     				</span>
#  <span>
#     					microservices architecture
#     				</span>
#  <span>
#     					apache
#     				</span>
#  <span>
#     					git
#     				</span>
#  <span>
#     					docker
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Pune">
#  <i class="srp-icons location"></i>
#
#                Pune
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>4 - 8 Years</li>
#  <li><i class="srp-icons salary"></i>Not disclosed</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70699838">
#  <a class="apply-btn" href="javascript:callExtJobApply('70699838','adId=FlEnn8GTIRdzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70699838','fullstack development   ,  angular framework   ,  mongodb database   ,  java spring boot   ,  microservices architecture   , apache , git , docker','Pune','4 - 8','IT Software : Software Products &amp; Services','10','')">View Details</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Pune
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/java-angular-4-to-8-years-pune-hyderabad-capgemini-india-pvt-ltd-pune-4-to-8-yrs-jobid-FlEnn8GTIRdzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70699838','fullstack development   ,  angular framework   ,  mongodb database   ,  java spring boot   ,  microservices architecture   , apache , git , docker','Pune','4 - 8','IT Software : Software Products &amp; Services','10','' )" target="_blank"></a>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000291.png" alt="Capgemini India Pvt Ltd" title="Capgemini India Pvt Ltd"/> </span> -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container"><img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000291.png"/>
#  </span>
#  <div>
#  <h2 class="heading-trun" title="Angular | 4 to 8 years | Pune &amp; Hyderabad">
#  <a href="https://www.timesjobs.com/job-detail/angular-4-to-8-years-pune-hyderabad-capgemini-india-pvt-ltd-pune-4-to-8-yrs-jobid-OnpBWRa1T11zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70699832','angular development  ,  mongodb management  ,  java  experience  ,  spring boot framework  ,  microservices architecture  , apache , git , docker','Pune','4 - 8','IT Software : Software Products &amp; Services','11','' )" target="_blank">
#        Angular | 4 to 8 years | Pune &amp; Hyderabad</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    Capgemini India Pvt Ltd
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			4 to 8 years of experience in ANGULAR, MONGODB.Hands-on experience in webservices, microservices, Java 8 , Spring Boot.Good to HaveWork in the followi...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					angular development
#     				</span>
#  <span>
#     					mongodb management
#     				</span>
#  <span>
#     					java  experience
#     				</span>
#  <span>
#     					spring boot framework
#     				</span>
#  <span>
#     					microservices architecture
#     				</span>
#  <span>
#     					apache
#     				</span>
#  <span>
#     					git
#     				</span>
#  <span>
#     					docker
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Pune">
#  <i class="srp-icons location"></i>
#
#                Pune
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>4 - 8 Years</li>
#  <li><i class="srp-icons salary"></i>Not disclosed</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70699832">
#  <a class="apply-btn" href="javascript:callExtJobApply('70699832','adId=OnpBWRa1T11zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70699832','angular development  ,  mongodb management  ,  java  experience  ,  spring boot framework  ,  microservices architecture  , apache , git , docker','Pune','4 - 8','IT Software : Software Products &amp; Services','11','')">View Details</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Pune
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/angular-4-to-8-years-pune-hyderabad-capgemini-india-pvt-ltd-pune-4-to-8-yrs-jobid-OnpBWRa1T11zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70699832','angular development  ,  mongodb management  ,  java  experience  ,  spring boot framework  ,  microservices architecture  , apache , git , docker','Pune','4 - 8','IT Software : Software Products &amp; Services','11','' )" target="_blank"></a>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000291.png" alt="Capgemini India Pvt Ltd" title="Capgemini India Pvt Ltd"/> </span> -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container"><img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000291.png"/>
#  </span>
#  <div>
#  <h2 class="heading-trun" title="System Engineer(SAP BASIS WITH HANA) | 6 to 9 YEARS | MUMBAI, PUNE &amp; BENGALURU">
#  <a href="https://www.timesjobs.com/job-detail/system-engineer-sap-basis-with-hana-6-to-9-years-mumbai-pune-bengaluru-capgemini-india-pvt-ltd-kolkata-3-to-5-yrs-jobid-lJdk9dU91Q5zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70699828','sap basis administration  ,  hana database management  ,  performance tuning  ,  user administration  ,  abap dump analysis  , netweaver , java , sap hana , sybase , client administration , sap fiori , infrastructure','Kolkata','3 - 5','IT Software : Software Products &amp; Services','12','' )" target="_blank">
#        System Engineer(SAP BASIS WITH HANA) | 6 to 9 YEARS | MUMBAI, PUNE &amp; BENGALURU</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    Capgemini India Pvt Ltd
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			Choosing Capgemini means choosing a company where you will be empowered to shape your career in the way youd like, where youll be supported and inspir...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					sap basis administration
#     				</span>
#  <span>
#     					hana database management
#     				</span>
#  <span>
#     					performance tuning
#     				</span>
#  <span>
#     					user administration
#     				</span>
#  <span>
#     					abap dump analysis
#     				</span>
#  <span>
#     					netweaver
#     				</span>
#  <span>
#     					java
#     				</span>
#  <span>
#     					sap hana
#     				</span>
#  <span>
#     					sybase
#     				</span>
#  <span>
#     					client administration
#     				</span>
#  <span>
#     					sap fiori
#     				</span>
#  <span>
#     					infrastructure
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Kolkata">
#  <i class="srp-icons location"></i>
#
#                Kolkata
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>3 - 5 Years</li>
#  <li><i class="srp-icons salary"></i>Not disclosed</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70699828">
#  <a class="apply-btn" href="javascript:callExtJobApply('70699828','adId=lJdk9dU91Q5zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70699828','sap basis administration  ,  hana database management  ,  performance tuning  ,  user administration  ,  abap dump analysis  , netweaver , java , sap hana , sybase , client administration , sap fiori , infrastructure','Kolkata','3 - 5','IT Software : Software Products &amp; Services','12','')">View Details</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Kolkata
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/system-engineer-sap-basis-with-hana-6-to-9-years-mumbai-pune-bengaluru-capgemini-india-pvt-ltd-kolkata-3-to-5-yrs-jobid-lJdk9dU91Q5zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70699828','sap basis administration  ,  hana database management  ,  performance tuning  ,  user administration  ,  abap dump analysis  , netweaver , java , sap hana , sybase , client administration , sap fiori , infrastructure','Kolkata','3 - 5','IT Software : Software Products &amp; Services','12','' )" target="_blank"></a>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/002682.gif" alt="McAfee Software  ( India )  Pvt Ltd" title="McAfee Software  ( India )  Pvt Ltd"/> </span> -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container"><img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/002682.gif"/>
#  </span>
#  <div>
#  <h2 class="heading-trun" title="Senior Data Curation Engineer - Remote">
#  <a href="https://www.timesjobs.com/job-detail/senior-data-curation-engineer-remote-mcafee-software-india-pvt-ltd-canada-3-to-5-yrs-jobid-Mb2X2oEwWsVzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70704074','database modeling  ,  etl / elt processes  ,  data aggregation  ,  data curation design  ,  sql / sparksql proficiency  , bi , security , data modeling , data structures , data profiling , data engineer , data quality , tandem','Canada','3 - 5','IT Software : Software Products &amp; Services','13','' )" target="_blank">
#        Senior Data Curation Engineer - Remote</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    McAfee Software  ( India )  Pvt Ltd
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			Role OverviewWe are seeking a seasoned data engineer to join our Enterprise Analytics team as a Data Curation Engineer, reporting to the Capability Le...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					database modeling
#     				</span>
#  <span>
#     					etl / elt processes
#     				</span>
#  <span>
#     					data aggregation
#     				</span>
#  <span>
#     					data curation design
#     				</span>
#  <span>
#     					sql / sparksql proficiency
#     				</span>
#  <span>
#     					bi
#     				</span>
#  <span>
#     					security
#     				</span>
#  <span>
#     					data modeling
#     				</span>
#  <span>
#     					data structures
#     				</span>
#  <span>
#     					data profiling
#     				</span>
#  <span>
#     					data engineer
#     				</span>
#  <span>
#     					data quality
#     				</span>
#  <span>
#     					tandem
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
# ...
#        Performance Architect</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    IBM India Pvt Ltd
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			IntroductionAt IBM, work is more than a job  its a calling: To build. To design. To code. To consult. To think along with clients and sell. To make ma...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					performance testing
#     				</span>
#  <span>
#     					software quality assurance
#     				</span>
#  <span>
#     					programming in python
#     				</span>
#  <span>
#     					cloud services experience
#     				</span>
#  <span>
#     					ai and llm knowledge
#     				</span>
#  <span>
#     					devops
#     				</span>
#  <span>
#     					linux
#     				</span>
#  <span>
#     					shell scripting
#     				</span>
#  <span>
#     					software engineering
#     				</span>
#  <span>
#     					team player
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Bengaluru / Bangalore">
#  <i class="srp-icons location"></i>
#
#                Bengaluru / Bangalore
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>3 - 5 Years</li>
#  <li><i class="srp-icons salary"></i>Not disclosed</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70703981">
#  <a class="apply-btn" href="javascript:callExtJobApply('70703981','adId=yo__PLUS__3__SLASH__mvLXydzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70703981','performance testing   ,  software quality assurance   ,  programming in python   ,  cloud services experience   ,  ai and llm knowledge   , devops , linux , shell scripting , software engineering , team player','Bengaluru / Bangalore','3 - 5','IT Software : Software Products &amp; Services','22','')">View Details</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Bengaluru / Bangalore
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/performance-architect-ibm-india-pvt-ltd-bengaluru-bangalore-3-to-5-yrs-jobid-yo__PLUS__3__SLASH__mvLXydzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70703981','performance testing   ,  software quality assurance   ,  programming in python   ,  cloud services experience   ,  ai and llm knowledge   , devops , linux , shell scripting , software engineering , team player','Bengaluru / Bangalore','3 - 5','IT Software : Software Products &amp; Services','22','' )" target="_blank"></a>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000597.gif" alt="IBM India Pvt Ltd" title="IBM India Pvt Ltd"/> </span> -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container"><img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000597.gif"/>
#  </span>
#  <div>
#  <h2 class="heading-trun" title="Sr. iOS Mobile Developer">
#  <a href="https://www.timesjobs.com/job-detail/sr-ios-mobile-developer-ibm-india-pvt-ltd-bengaluru-bangalore-5-to-7-yrs-jobid-UTchlRpEhdtzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70703980','full stack development   ,  ios mobile development   ,  solution architecture   ,  cloud platforms   ,  programming languages   , websphere , css , sql , java , git , software engineering , python , cakephp , laravel , javascript , nosql , spring boot , django , infrastructure , project delivery','Bengaluru / Bangalore','5 - 7','IT Software : Software Products &amp; Services','23','' )" target="_blank">
#        Sr. iOS Mobile Developer</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    IBM India Pvt Ltd
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			IntroductionAs an Application Developer, you will lead IBM into the future by translating system requirements into the design and development of custo...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					full stack development
#     				</span>
#  <span>
#     					ios mobile development
#     				</span>
#  <span>
#     					solution architecture
#     				</span>
#  <span>
#     					cloud platforms
#     				</span>
#  <span>
#     					programming languages
#     				</span>
#  <span>
#     					websphere
#     				</span>
#  <span>
#     					css
#     				</span>
#  <span>
#     					sql
#     				</span>
#  <span>
#     					java
#     				</span>
#  <span>
#     					git
#     				</span>
#  <span>
#     					software engineering
#     				</span>
#  <span>
#     					python
#     				</span>
#  <span>
#     					cakephp
#     				</span>
#  <span>
#     					laravel
#     				</span>
#  <span>
#     					javascript
#     				</span>
#  <span>
#     					nosql
#     				</span>
#  <span>
#     					spring boot
#     				</span>
#  <span>
#     					django
#     				</span>
#  <span>
#     					infrastructure
#     				</span>
#  <span>
#     					project delivery
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Bengaluru / Bangalore">
#  <i class="srp-icons location"></i>
#
#                Bengaluru / Bangalore
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>5 - 7 Years</li>
#  <li><i class="srp-icons salary"></i>Not disclosed</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70703980">
#  <a class="apply-btn" href="javascript:callExtJobApply('70703980','adId=UTchlRpEhdtzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70703980','full stack development   ,  ios mobile development   ,  solution architecture   ,  cloud platforms   ,  programming languages   , websphere , css , sql , java , git , software engineering , python , cakephp , laravel , javascript , nosql , spring boot , django , infrastructure , project delivery','Bengaluru / Bangalore','5 - 7','IT Software : Software Products &amp; Services','23','')">View Details</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Bengaluru / Bangalore
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/sr-ios-mobile-developer-ibm-india-pvt-ltd-bengaluru-bangalore-5-to-7-yrs-jobid-UTchlRpEhdtzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70703980','full stack development   ,  ios mobile development   ,  solution architecture   ,  cloud platforms   ,  programming languages   , websphere , css , sql , java , git , software engineering , python , cakephp , laravel , javascript , nosql , spring boot , django , infrastructure , project delivery','Bengaluru / Bangalore','5 - 7','IT Software : Software Products &amp; Services','23','' )" target="_blank"></a>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000597.gif" alt="IBM India Pvt Ltd" title="IBM India Pvt Ltd"/> </span> -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container"><img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000597.gif"/>
#  </span>
#  <div>
#  <h2 class="heading-trun" title="Data Engineer: Data Platforms-Google">
#  <a href="https://www.timesjobs.com/job-detail/data-engineer-data-platforms-google-ibm-india-pvt-ltd-chennai-5-to-7-yrs-jobid-d__PLUS__b4hqiPqKlzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70703946','gcp services expertise  ,  python programming  ,  sql database management  ,  data analysis skills  ,  agile methodologies  , composer','Chennai','5 - 7','IT Software : Software Products &amp; Services','24','' )" target="_blank">
#        Data Engineer: Data Platforms-Google</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    IBM India Pvt Ltd
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			IntroductionIn this role, youll work in one of our IBM Consulting Client Innovation Centers (Delivery Centers), where we deliver deep technical and in...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					gcp services expertise
#     				</span>
#  <span>
#     					python programming
#     				</span>
#  <span>
#     					sql database management
#     				</span>
#  <span>
#     					data analysis skills
#     				</span>
#  <span>
#     					agile methodologies
#     				</span>
#  <span>
#     					composer
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Chennai">
#  <i class="srp-icons location"></i>
#
#                Chennai
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>5 - 7 Years</li>
#  <li><i class="srp-icons salary"></i>Not disclosed</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70703946">
#  <a class="apply-btn" href="javascript:callExtJobApply('70703946','adId=d__PLUS__b4hqiPqKlzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70703946','gcp services expertise  ,  python programming  ,  sql database management  ,  data analysis skills  ,  agile methodologies  , composer','Chennai','5 - 7','IT Software : Software Products &amp; Services','24','')">View Details</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Chennai
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/data-engineer-data-platforms-google-ibm-india-pvt-ltd-chennai-5-to-7-yrs-jobid-d__PLUS__b4hqiPqKlzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70703946','gcp services expertise  ,  python programming  ,  sql database management  ,  data analysis skills  ,  agile methodologies  , composer','Chennai','5 - 7','IT Software : Software Products &amp; Services','24','' )" target="_blank"></a>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000597.gif" alt="IBM India Pvt Ltd" title="IBM India Pvt Ltd"/> </span> -->
#  <div class="d-flex d-flex-l-r job-title__logo">
#  <div class="d-flex d-flex-l-r">
#  <span class="logo-container"><img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/000597.gif"/>
#  </span>
#  <div>
#  <h2 class="heading-trun" title="Application Developer: Microsoft Dynamics 365 Finance &amp; Operations">
#  <a href="https://www.timesjobs.com/job-detail/application-developer-microsoft-dynamics-365-finance-operations-ibm-india-pvt-ltd-kolkata-5-to-8-yrs-jobid-RFhjRSvY0NtzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70703935','x   and c#  ,  technical solution design  ,  process customization  ,  api integration services  ,  custom reporting ssrs  , rest , environment management , software engineering , soap','Kolkata','5 - 8','IT Software : Software Products &amp; Services','25','' )" target="_blank">
#        Application Developer: Microsoft Dynamics 365 Finance &amp; Operations</a> </h2>
#  <div class="d-flex d-flex-align-item">
#  <h3 class="joblist-comp-name">
#  		    IBM India Pvt Ltd
#
#  		    </h3>
#  <span class="sim-posted">
#  <span>Posted today</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </header>
#  <ul class="list-job-dtl clearfix">
#  <li class="job-description__">
#  			IntroductionIn this role, youll work in one of our IBM Consulting Client Innovation Centers (Delivery Centers), where we deliver deep technical and in...
#       	 </li>
#  <li>
#  <div class="srp-skills">
#  <!-- The fixed Length to compare against -->
#  <div class="more-skills-sections">
#  <span>
#     					x   and c#
#     				</span>
#  <span>
#     					technical solution design
#     				</span>
#  <span>
#     					process customization
#     				</span>
#  <span>
#     					api integration services
#     				</span>
#  <span>
#     					custom reporting ssrs
#     				</span>
#  <span>
#     					rest
#     				</span>
#  <span>
#     					environment management
#     				</span>
#  <span>
#     					software engineering
#     				</span>
#  <span>
#     					soap
#     				</span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <div class="d-flex d-flex-l-r d-flex-align-item">
#  <ul class="top-jd-dtl mt-16 clearfix">
#  <li class="srp-zindex location-tru" title="Kolkata">
#  <i class="srp-icons location"></i>
#
#                Kolkata
#
#
#
#                </li>
#  <li><i class="srp-icons experience"></i>5 - 8 Years</li>
#  <li><i class="srp-icons salary"></i>Not disclosed</li>
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70703935">
#  <a class="apply-btn" href="javascript:callExtJobApply('70703935','adId=RFhjRSvY0NtzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70703935','x   and c#  ,  technical solution design  ,  process customization  ,  api integration services  ,  custom reporting ssrs  , rest , environment management , software engineering , soap','Kolkata','5 - 8','IT Software : Software Products &amp; Services','25','')">View Details</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                Kolkata
#                </li>
#  -->
#  <a class="posoverlay_srp" href="https://www.timesjobs.com/job-detail/application-developer-microsoft-dynamics-365-finance-operations-ibm-india-pvt-ltd-kolkata-5-to-8-yrs-jobid-RFhjRSvY0NtzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70703935','x   and c#  ,  technical solution design  ,  process customization  ,  api integration services  ,  custom reporting ssrs  , rest , environment management , software engineering , soap','Kolkata','5 - 8','IT Software : Software Products &amp; Services','25','' )" target="_blank"></a>
#  </li>]

# %%
res=soup.find('i','experience')
print(type(res.next_sibling))
# Out:
# <class 'bs4.element.NavigableString'>

# %%
def Get_Job_Details(bs_obj):
    ans={}
    res=bs_obj.find_all('li',class_='job-bx')
    
    for item in res:
        k=item.a.string.strip().strip('\t').strip('\n')
        ans[k]={}
        ans[k]['Hosted By']=item.h3.string.strip().strip('\t').strip('\n')
        ans[k]['Job Description']=item.find('li',class_='job-description__').string.strip().strip('\t').strip('\n')
        ans[k]['Location']=list(item.find('li',class_='location-tru').children)[-1].strip().strip('\t').strip('\n')
        ans[k]['Experience']=item.find('i','experience').next_sibling
        ans[k]['Salary']=str(item.find('i','salary').next_sibling).replace(' ','').replace('\t','').replace('\n','')
        ans[k]['Posted']=str(list(item.find('span',class_='sim-posted').children)[1].string)
    return ans

# %%
IT_jobs_details=Get_Job_Details(soup)

# %%
IT_jobs_details
# Out:
# {'Manual Test Engineer Required in Canada Under PNP program': {'Hosted By': 'World Overseas immigration Consultancy Pvt Ltd',
#   'Job Description': 'Work with developers to design algorithms and flowcharts.Produce clean, efficient code based on specifications.Integrate software components and third...',
#   'Location': 'Australia,  Canada',
#   'Experience': '2 - 7 Years',
#   'Salary': '39-44Lakhs',
#   'Posted': 'Posted today'},
#  'Power Platform Developer': {'Hosted By': 'D B Consultancy',
#   'Job Description': 'Urgent opening for Power Platform Developer-Pune/BangalorePosition:Power Platform DeveloperExperience:5+YearsBudget:10-12LPA(Slightly negotiable)Locat...',
#   'Location': 'Bengaluru / Bangalore,  Pune',
#   'Experience': '5 - 10 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Software Engineer\\Sr. Software Engineer - J48459': {'Hosted By': 'SAMPOORNA CONSULTANTS PVT LTD',
#   'Job Description': 'Knowledge/Qualifications/ Technical Competencies Knowledge, Skills & Abilities:  Develop and maintain automated test suites, using Python/Scala/C#...',
#   'Location': 'Bengaluru / Bangalore',
#   'Experience': '4 - 7 Years',
#   'Salary': '7-20Lakhs',
#   'Posted': 'Posted today'},
#  'Innovation Engineer - AI - J48457': {'Hosted By': 'SAMPOORNA CONSULTANTS PVT LTD',
#   'Job Description': 'As an Innovation Engineer at , you will collaborate with technical teams to identify andimplement opportunities to apply AI, machine learning, and adv...',
#   'Location': 'Bengaluru / Bangalore,  Chennai',
#   'Experience': '3 - 5 Years',
#   'Salary': '6-13Lakhs',
#   'Posted': 'Posted today'},
#  'Data Analyst - AI/ML - J48458': {'Hosted By': 'SAMPOORNA CONSULTANTS PVT LTD',
#   'Job Description': 'Data Analyst :At least 2 years of experience in data analysis, data engineering, or a similar role. Proficient in SQL and at least one programming lan...',
#   'Location': 'Chennai',
#   'Experience': '3 - 5 Years',
#   'Salary': '6-13Lakhs',
#   'Posted': 'Posted today'},
#  '.NET  API + Azure-(UK) - Con- BLR - J48411': {'Hosted By': 'SAMPOORNA CONSULTANTS PVT LTD',
#   'Job Description': 'Key Responsibilities:Design, develop, and maintain software applications using C# and .NET.Collaborate with the team to build responsive front-end int...',
#   'Location': 'Bengaluru / Bangalore',
#   'Experience': '5 - 6 Years',
#   'Salary': '12-22Lakhs',
#   'Posted': 'Posted today'},
#  'Systems Engineer - C': {'Hosted By': 'Capgemini India Pvt Ltd',
#   'Job Description': 'Responsible for the operations and maintenance of On Premise or client dedicated computing platforms and servers. They install, maintain, patch, upgra...',
#   'Location': 'Bengaluru / Bangalore',
#   'Experience': '3 - 5 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Senior Software Engineer - C': {'Hosted By': 'Capgemini India Pvt Ltd',
#   'Job Description': 'Responsible for the Configuration, Testing, Troubleshooting, and Operations of Ericsson PaCo Nes(vSGSN-MME, vEPG, WMG).Must have a strong understandin...',
#   'Location': 'Gurgaon',
#   'Experience': '3 - 5 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Data Engineer - C': {'Hosted By': 'Capgemini India Pvt Ltd',
#   'Job Description': 'Data engineers are responsible for building reliable and scalable data infrastructure that enables organizations to derive meaningful insights, make d...',
#   'Location': 'Pune',
#   'Experience': '5 - 8 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Java Angular | 4 to 8 years | Pune & Hyderabad': {'Hosted By': 'Capgemini India Pvt Ltd',
#   'Job Description': 'Experience: 4 to 8 years in FULLSTACK ANGULAR, MONGODB.Technical Skills: Hands-on experience in web services, microservices, Java 8 , Spring Boot.Good...',
#   'Location': 'Pune',
#   'Experience': '4 - 8 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Angular | 4 to 8 years | Pune & Hyderabad': {'Hosted By': 'Capgemini India Pvt Ltd',
#   'Job Description': '4 to 8 years of experience in ANGULAR, MONGODB.Hands-on experience in webservices, microservices, Java 8 , Spring Boot.Good to HaveWork in the followi...',
#   'Location': 'Pune',
#   'Experience': '4 - 8 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'System Engineer(SAP BASIS WITH HANA) | 6 to 9 YEARS | MUMBAI, PUNE & BENGALURU': {'Hosted By': 'Capgemini India Pvt Ltd',
#   'Job Description': 'Choosing Capgemini means choosing a company where you will be empowered to shape your career in the way youd like, where youll be supported and inspir...',
#   'Location': 'Kolkata',
#   'Experience': '3 - 5 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Senior Data Curation Engineer - Remote': {'Hosted By': 'McAfee Software  ( India )  Pvt Ltd',
#   'Job Description': 'Role OverviewWe are seeking a seasoned data engineer to join our Enterprise Analytics team as a Data Curation Engineer, reporting to the Capability Le...',
#   'Location': 'Canada',
#   'Experience': '3 - 5 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Business Advisor - B': {'Hosted By': 'Capgemini India Pvt Ltd',
#   'Job Description': 'Business Advisors shape the vision with the client, understand the needs of the users/stakeholders, carry out an elicitation of processes, data and ca...',
#   'Location': 'Chennai',
#   'Experience': '5 - 8 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Senior Tradeshows & Events Specialist EMEA (maternity cover) Job Details | Boston Scientific': {'Hosted By': 'BOSTON SCIENTIFIC',
#   'Job Description': 'Senior Tradeshows &amp; Events Specialist EMEA (maternity cover)Work mode: HybridOnsite Location(s): Warsaw, PolandAdditional Locations: N/ADivers...',
#   'Location': 'Germany,  null',
#   'Experience': '5 - 8 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Sr, Data Engineer HEREDIA Job Details | Boston Scientific': {'Hosted By': 'BOSTON SCIENTIFIC',
#   'Job Description': 'Sr, Data Engineer HEREDIAWork mode: OnsiteOnsite Location(s): Heredia, H, CRAdditional Locations: Costa Rica-HerediaDiversity - Innovation - Caring - ...',
#   'Location': '',
#   'Experience': '5 - 8 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Guidewire Developer | 6 to 12 years | PAN India': {'Hosted By': 'Capgemini India Pvt Ltd',
#   'Job Description': 'Guidewire Developer:Guidewire Policy integration / guidewire Policy configurationORGuidewire billing integration / guidewire billing configurationORGu...',
#   'Location': 'Hyderabad/Secunderabad',
#   'Experience': '3 - 5 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Project Manager, Technical Job Details | Boston Scientific': {'Hosted By': 'BOSTON SCIENTIFIC',
#   'Job Description': 'Project Manager, TechnicalWork mode: HybridOnsite Location(s): Gurgaon, HR, INAdditional Locations: India-Haryana, GurgaonDiversity - Innovation - Car...',
#   'Location': 'Gurgaon',
#   'Experience': '10 - 13 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Vedlikeholdstekniker elektro Job Details | ExxonMobil': {'Hosted By': 'Exxonmobil Company India Pvt Ltd',
#   'Job Description': 'Vedlikeholdstekniker elektroLocation: Slagen, 03, NOCompany: EssoOm ossVi sker en ny medarbeider til vr terminal p Slagentangen utenfor Tnsberg.Elektr...',
#   'Location': 'Norway',
#   'Experience': '3 - 5 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Business Transformation Consultant: IoT & PLM': {'Hosted By': 'IBM India Pvt Ltd',
#   'Job Description': 'IntroductionIn this role, youll work in one of our IBM Consulting Client Innovation Centers (Delivery Centers), where we deliver deep technical and in...',
#   'Location': 'Pune',
#   'Experience': '5 - 7 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Server I/O Logic Design': {'Hosted By': 'IBM India Pvt Ltd',
#   'Job Description': 'IntroductionThe Server IO logic design team delivers both proprietary and industry standard interfaces for IBMs POWER systems and Z Mainframe processo...',
#   'Location': 'Bengaluru / Bangalore',
#   'Experience': '7 - 10 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Performance Architect': {'Hosted By': 'IBM India Pvt Ltd',
#   'Job Description': 'IntroductionAt IBM, work is more than a job  its a calling: To build. To design. To code. To consult. To think along with clients and sell. To make ma...',
#   'Location': 'Bengaluru / Bangalore',
#   'Experience': '3 - 5 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Sr. iOS Mobile Developer': {'Hosted By': 'IBM India Pvt Ltd',
#   'Job Description': 'IntroductionAs an Application Developer, you will lead IBM into the future by translating system requirements into the design and development of custo...',
#   'Location': 'Bengaluru / Bangalore',
#   'Experience': '5 - 7 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Data Engineer: Data Platforms-Google': {'Hosted By': 'IBM India Pvt Ltd',
#   'Job Description': 'IntroductionIn this role, youll work in one of our IBM Consulting Client Innovation Centers (Delivery Centers), where we deliver deep technical and in...',
#   'Location': 'Chennai',
#   'Experience': '5 - 7 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'},
#  'Application Developer: Microsoft Dynamics 365 Finance & Operations': {'Hosted By': 'IBM India Pvt Ltd',
#   'Job Description': 'IntroductionIn this role, youll work in one of our IBM Consulting Client Innovation Centers (Delivery Centers), where we deliver deep technical and in...',
#   'Location': 'Kolkata',
#   'Experience': '5 - 8 Years',
#   'Salary': 'Notdisclosed',
#   'Posted': 'Posted today'}}

# %% [markdown]
# #### OBTAIN JOBS THAT WERE RECENTLY POSTED

# %%
type(IT_jobs_details['Angular | 4 to 8 years | Pune & Hyderabad']['Posted'])
# Out:
# str

# %%
import regex as re

# %%
def Obtain_Jobs_Recently_Posted(doc):
    ans=[]
    for item in doc:
        if re.search('today',doc[item]['Posted']) or re.search('a few days ago',doc[item]['Posted']):
            ans.append(item)
    return ans

# %%
res=Obtain_Jobs_Recently_Posted(IT_jobs_details)

# %%
res
# Out:
# ['Manual Test Engineer Required in Canada Under PNP program',
#  'Power Platform Developer',
#  'Software Engineer\\Sr. Software Engineer - J48459',
#  'Innovation Engineer - AI - J48457',
#  'Data Analyst - AI/ML - J48458',
#  '.NET  API + Azure-(UK) - Con- BLR - J48411',
#  'Systems Engineer - C',
#  'Senior Software Engineer - C',
#  'Data Engineer - C',
#  'Java Angular | 4 to 8 years | Pune & Hyderabad',
#  'Angular | 4 to 8 years | Pune & Hyderabad',
#  'System Engineer(SAP BASIS WITH HANA) | 6 to 9 YEARS | MUMBAI, PUNE & BENGALURU',
#  'Senior Data Curation Engineer - Remote',
#  'Business Advisor - B',
#  'Senior Tradeshows & Events Specialist EMEA (maternity cover) Job Details | Boston Scientific',
#  'Sr, Data Engineer HEREDIA Job Details | Boston Scientific',
#  'Guidewire Developer | 6 to 12 years | PAN India',
#  'Project Manager, Technical Job Details | Boston Scientific',
#  'Vedlikeholdstekniker elektro Job Details | ExxonMobil',
#  'Business Transformation Consultant: IoT & PLM',
#  'Server I/O Logic Design',
#  'Performance Architect',
#  'Sr. iOS Mobile Developer',
#  'Data Engineer: Data Platforms-Google',
#  'Application Developer: Microsoft Dynamics 365 Finance & Operations']

# %% [markdown]
# Above we find the list of jobs posted either **a few days ago** or **on the current day when viewed**
